# %% [markdown]
# Marcjanna Bąkowska \
# https://github.com/marczef/analiza-i-bazy-danych.git \
# Zadanie 3
# Wykres funkcji $f(x) = {x}^2 + 5$
# 1. dla $x>-1$ i $x<1$

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

#wykresy funckji dla trzech poszczególnych wartości x

f_x = lambda x: x**2 + 5
x_1 = np.linspace(-1, 1, 1000)
y_1 = f_x(x_1)

plt.plot(x_1, y_1, "b", label = "x^2 + 5")
plt.title("Wykres funkcji dla x>-1 x<1")
plt.legend()
plt.ylabel("y(x)")
plt.xlabel("x")
plt.grid()
plt.show()

# %% [markdown]
# 2. dla $x>-6$ i $x<6$

# %%
x_2 = np.linspace(-6, 6, 1000)
y_2 = f_x(x_2)

plt.plot(x_2, y_2, "r", label = "x^2 + 5")
plt.title("Wykres funkcji dla x>-6 x<6")
plt.legend()
plt.ylabel("y(x)")
plt.xlabel("x")
plt.grid()
plt.show()

# %% [markdown]
# 2. dla $x>0$ i $x<5$

# %%
x_3 = np.linspace(0, 5, 1000)
y_3 = f_x(x_3)

plt.plot(x_3, y_3, "g", label = "x^2 + 5")
plt.title("Wykres funkcji dla x>0 x<5")
plt.legend()
plt.ylabel("y(x)")
plt.xlabel("x")
plt.grid()
plt.show()

# %% [markdown]
# Zadanie 4

# %%
import pandas

#pandas dataframe z przykładowymi danymi

d = {'name': ['Wladyslaw', 'Eugeniusz', 'Edyta', 'Anastazja'], 'surname': ['Niezimkiewicz', 'Wiosnkowicz', 'Letnikowski', 'Jesierniara'],
     'age': [67, 45, 30, 18], 'sex': ['male', 'male', 'female', 'female']}
info = pandas.DataFrame(data=d)
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     4 non-null      object
#  1   surname  4 non-null      object
#  2   age      4 non-null      int64
#  3   sex      4 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 256.0+ bytes

# %%
info.describe(include='all')
# Out:
#              name        surname        age   sex
# count           4              4   4.000000     4
# unique          4              4        NaN     2
# top     Wladyslaw  Niezimkiewicz        NaN  male
# freq            1              1        NaN     2
# mean          NaN            NaN  40.000000   NaN
# std           NaN            NaN  21.118712   NaN
# min           NaN            NaN  18.000000   NaN
# 25%           NaN            NaN  27.000000   NaN
# 50%           NaN            NaN  37.500000   NaN
# 75%           NaN            NaN  50.500000   NaN
# max           NaN            NaN  67.000000   NaN

# %%
info.head(3)
# Out:
#         name        surname  age     sex
# 0  Wladyslaw  Niezimkiewicz   67    male
# 1  Eugeniusz    Wiosnkowicz   45    male
# 2      Edyta    Letnikowski   30  female
